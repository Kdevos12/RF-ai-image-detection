# %%
import kagglehub
import cv2
import numpy as np
from skimage.feature import graycomatrix, graycoprops
from scipy.stats import skew, kurtosis
from skimage import measure
import pandas as pd

# Download latest version
path = kagglehub.dataset_download("alessandrasala79/ai-vs-human-generated-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/ai-vs-human-generated-dataset

# %%
def analyze_image(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
 
    blurred_image = cv2.GaussianBlur(image, (5, 5), 0)

    # Calculer la moyenne et l'écart type des valeurs des pixels
    mean_pixel_value, stddev_pixel_value = cv2.meanStdDev(blurred_image)

    # Définir les seuils pour la détection d'artéfacts (moyenne ± 2*écart type)
    lower_threshold = mean_pixel_value - 2 * stddev_pixel_value
    upper_threshold = mean_pixel_value + 2 * stddev_pixel_value

    # Calculer l'asymétrie (skewness) et la kurtose
    flattened_pixels = image.flatten()
    image_skewness = skew(flattened_pixels)
    image_kurtosis = kurtosis(flattened_pixels)
    
    # Effectuer l'analyse de Fourier
    def perform_fourier_analysis(image_path):
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        fourier_transform = np.fft.fft2(image)
        fourier_shift = np.fft.fftshift(fourier_transform)
        magnitude_spectrum = np.abs(fourier_shift)
        log_magnitude_spectrum = np.log(1 + magnitude_spectrum)
        mean_magnitude = np.mean(magnitude_spectrum)
        max_magnitude = np.max(magnitude_spectrum)
        return mean_magnitude, max_magnitude

    mean_fourier_magnitude, max_fourier_magnitude = perform_fourier_analysis(image_path)

    # Calcul de la cohérence de texture via GLCM
    def calculate_texture_coherence(image_path):
        image = cv2.imread(image_path)  
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        glcm = graycomatrix(gray_image, [1], [0], symmetric=True, normed=True)
        correlation = graycoprops(glcm, 'correlation')[0, 0]
        return correlation

    texture_coherence_correlation = calculate_texture_coherence(image_path)

    # Calcul de la non-uniformité des niveaux de gris (GLNU)
    def calculate_gray_level_non_uniformity(image):
        hist = cv2.calcHist([image], [0], None, [256], [0, 256])
        hist = hist / hist.sum()  
        glnu = np.sum(hist**2)
        return glnu

    # Calcul de la dimension fractale via la méthode de comptage par boîte
    def calculate_fractal_dimension(image):
        _, binary_image = cv2.threshold(image, 128, 255, cv2.THRESH_BINARY)
        binary_image = cv2.resize(binary_image, (128, 128))
        
        def box_count(img, box_size):
            count = 0
            for i in range(0, img.shape[0], box_size):
                for j in range(0, img.shape[1], box_size):
                    if np.sum(img[i:i+box_size, j:j+box_size] > 0):
                        count += 1
            return count

        sizes = np.arange(2, 20)
        counts = [box_count(binary_image, size) for size in sizes]
        log_sizes = np.log(sizes)
        log_counts = np.log(counts)
        coeffs = np.polyfit(log_sizes, log_counts, 1)
        fractal_dimension = -coeffs[0]
        return fractal_dimension

    gray_level_non_uniformity = calculate_gray_level_non_uniformity(image)
    fractal_dimension_value = calculate_fractal_dimension(image)

    # Calcul de l'entropie de la texture
    def calculate_texture_entropy(image):
        pixel_values = image.flatten() / 255.0  
        histogram, _ = np.histogram(pixel_values, bins=256, range=(0, 1))
        histogram = histogram / histogram.sum()
        entropy = -np.sum(histogram * np.log2(histogram + 1e-10))  
        return entropy
    
    texture_entropy_value = calculate_texture_entropy(image)

    def calculate_short_run_emphasis(glrlm):
        num = np.sum(glrlm * (np.arange(1, glrlm.shape[1] + 1) ** 2))
        den = np.sum(glrlm)
        return num / den if den != 0 else 0

    def calculate_glrlm(image):
        glrlm = np.zeros((256, image.shape[0] * image.shape[1]), dtype=int)
        for i in range(image.shape[0]):
            row = image[i, :]
            run_length = 1
            for j in range(1, len(row)):
                if row[j] == row[j - 1]:
                    run_length += 1
                else:
                    glrlm[row[j - 1], run_length - 1] += 1
                    run_length = 1
            glrlm[row[-1], run_length - 1] += 1
        return glrlm

    gray_level_run_length_matrix = calculate_glrlm(image)
    short_run_emphasis_value = calculate_short_run_emphasis(gray_level_run_length_matrix)

    # Variance spatiale
    def calculate_spatial_variance(image):
        return np.var(image)

    spatial_variance_value = calculate_spatial_variance(image)

    # Densité des bords (Edge Density)
    def calculate_edge_density(image):
        sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
        sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)
        magnitude = cv2.magnitude(sobel_x, sobel_y)
        edge_density_value = np.sum(magnitude > 50) / (image.size)
        return edge_density_value

    edge_density_value = calculate_edge_density(image)

    # Netteté (Sharpness)
    def calculate_sharpness(image):
        laplacian = cv2.Laplacian(image, cv2.CV_64F)
        sharpness_value = np.var(laplacian)
        return sharpness_value

    sharpness_value = calculate_sharpness(image)
    
    # Distribution des bords (Edge Distribution)
    def compute_edge_distribution(image):
        edges = cv2.Canny(image, 100, 200)
        edge_count = np.sum(edges > 0)
        edge_density = edge_count / (image.shape[0] * image.shape[1])
        edge_orientation = np.gradient(edges.astype(float))
        return edge_count, edge_density, np.std(edge_orientation)
        
    edge_count, edge_density, edge_orientation_std = compute_edge_distribution(image)

    

    # Retourner les résultats sous forme de dictionnaire
    results = {
        'artifact_detection_lower_threshold': lower_threshold[0][0],
        'artifact_detection_upper_threshold': upper_threshold[0][0],
        'skewness': image_skewness,
        'kurtosis': image_kurtosis,
        'fourier_mean_magnitude': mean_fourier_magnitude,
        'fourier_max_magnitude': max_fourier_magnitude,
        'texture_coherence_correlation': texture_coherence_correlation,
        'gray_level_non_uniformity': gray_level_non_uniformity,
        'fractal_dimension': fractal_dimension_value,
        'texture_entropy': texture_entropy_value,
        'short_run_emphasis': short_run_emphasis_value,
        'spatial_variance': spatial_variance_value,
        'sharpness': sharpness_value,
        'edge_count': edge_count,
        'edge_density': edge_density_value,
        'edge_orientation_std': edge_orientation_std,
    }

    return results

# %%
# Chargement des datasets
train_data = pd.read_csv('/kaggle/input/ai-vs-human-generated-dataset/train.csv')
test_data = pd.read_csv('/kaggle/input/ai-vs-human-generated-dataset/test.csv')
test_data.info()
# Chemins vers les répertoires d'images
image_dir = '/kaggle/input/ai-vs-human-generated-dataset'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19986 entries, 0 to 19985
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      19986 non-null  object
# dtypes: object(1)
# memory usage: 156.3+ KB

# %%
def preprocess_data(data, image_dir, max_samples=None):
    """
    Prétraite les données et applique l'analyse d'image.

    Args:
        data (pd.DataFrame): Le DataFrame contenant les informations sur les images.
        image_dir (str): Le répertoire contenant les images.
        max_samples (int, optional): Le nombre d'images à traiter. Par défaut, toutes les images sont traitées.
        
    Returns:
        pd.DataFrame: Un DataFrame avec les caractéristiques extraites de chaque image.
    """
    results = []

    data_subset = data.head(max_samples) if max_samples else data

    for idx, row in data_subset.iterrows():
        file_name = row['file_name'] if 'file_name' in row else row['id']
        image_path = f"{image_dir}/{file_name}"

        # Appliquer l'analyse de l'image
        try:
            analysis_results = analyze_image(image_path)
        except Exception as e:
            print(f"Erreur lors de l'analyse de l'image {file_name}: {e}")
            continue 

        result_dict = {'file_name': file_name, 'label': row.get('label', None)}  
        result_dict.update(analysis_results)
        print(result_dict)
        results.append(result_dict)

    # Convertir les résultats en DataFrame
    results_df = pd.DataFrame(results)
    
    return results_df

evaluation_data = train_data.sample(n=500, random_state=42)

train_data_remaining = train_data.drop(evaluation_data.index)

train_data_processed = preprocess_data(train_data_remaining, image_dir, max_samples=400)

evaluation_data_processed = preprocess_data(evaluation_data, image_dir, max_samples=400)



# Afficher les résultats des datasets prétraités
print(f"Ensemble d'entraînement (train_data) après prétraitement :\n{train_data_processed.head()}")
print(f"Ensemble d'évaluation (evaluation_data) après prétraitement :\n{evaluation_data_processed.head()}")
# Out:
# {'file_name': 'train_data/19b29cb2dd6c45a69999e1e3608b0982.jpg', 'label': 1, 'artifact_detection_lower_threshold': 27.121674127431817, 'artifact_detection_upper_threshold': 284.08900397315415, 'skewness': 0.3456089195297866, 'kurtosis': -1.614319457561353, 'fourier_mean_magnitude': 4157.4278672816245, 'fourier_max_magnitude': 61186191.0, 'texture_coherence_correlation': 0.9970015861770803, 'gray_level_non_uniformity': 0.01744541, 'fractal_dimension': 1.805766596524861, 'texture_entropy': 6.614374220916731, 'short_run_emphasis': 50.175106306755346, 'spatial_variance': 4161.592548344071, 'sharpness': 98.28561400226317, 'edge_count': 4281, 'edge_density': 0.043469746907552086, 'edge_orientation_std': 16.813539154702}
# {'file_name': 'train_data/76d24375c7ce4aa19fa50092ce335afd.jpg', 'label': 0, 'artifact_detection_lower_threshold': 120.98838516741523, 'artifact_detection_upper_threshold': 297.8802061411785, 'skewness': -2.642034700699907, 'kurtosis': 6.557784660049117, 'fourier_mean_magnitude': 5091.3714180280085, 'fourier_max_magnitude': 82353079.0, 'texture_coherence_correlation': 0.9834785963493176, 'gray_level_non_uniformity': 0.02784167, 'fractal_dimension': 1.9258396507395066, 'texture_entropy': 5.993704261431009, 'short_run_emphasis': 83.96722447195441, 'spatial_variance': 2019.5794978194492, 'sharpness': 255.7444727133067, 'edge_count': 14746, 'edge_density': 0.1417414347330729, 'edge_orientation_std': 29.47747499269473}
# {'file_name': 'train_data/58f88e4050a845428bc891badc334265.jpg', 'label': 0, 'artifact_detection_lower_threshold': 35.88802259344426, 'artifact_detection_upper_threshold': 267.5795236576408, 'skewness': -0.7723693741639936, 'kurtosis': -0.19972144475186004, 'fourier_mean_magnitude': 13974.263159332962, 'fourier_max_magnitude': 89495310.0, 'texture_coherence_correlation': 0.9462330159564109, 'gray_level_non_uniformity': 0.00549946, 'fractal_dimension': 1.8999375077306757, 'texture_entropy': 7.716339808084012, 'short_run_emphasis': 1.3782489542766478, 'spatial_variance': 3668.72467163112, 'sharpness': 2211.8033530594385, 'edge_count': 79193, 'edge_density': 0.5528666178385416, 'edge_orientation_std': 54.9122680859308}
# {'file_name': 'train_data/1c1b16b50b7a4801a42346e3a90c6c4c.jpg', 'label': 0, 'artifact_detection_lower_threshold': -6.906641526358555, 'artifact_detection_upper_threshold': 204.200693650382, 'skewness': 0.6099824089876608, 'kurtosis': -0.32662254625797216, 'fourier_mean_magnitude': 9856.058330080947, 'fourier_max_magnitude': 38788064.0, 'texture_coherence_correlation': 0.9586847198506584, 'gray_level_non_uniformity': 0.005474957, 'fractal_dimension': 1.7030780015347502, 'texture_entropy': 7.681647076129611, 'short_run_emphasis': 2.0625969522766674, 'spatial_variance': 3046.448060346974, 'sharpness': 1150.367856004353, 'edge_count': 56023, 'edge_density': 0.46304066975911456, 'edge_orientation_std': 57.20334493637114}
# {'file_name': 'train_data/5a16c753699341598768065d9ea82e7a.jpg', 'label': 1, 'artifact_detection_lower_threshold': 2.796258999363573, 'artifact_detection_upper_threshold': 216.32874608689943, 'skewness': 0.39860177245528555, 'kurtosis': -0.4129307546614962, 'fourier_mean_magnitude': 13525.916512769874, 'fourier_max_magnitude': 43081709.0, 'texture_coherence_correlation': 0.8791740661859786, 'gray_level_non_uniformity': 0.005050777, 'fractal_dimension': 1.8304554994190294, 'texture_entropy': 7.74702832694253, 'short_run_emphasis': 1.2500920592512157, 'spatial_variance': 3499.064520197759, 'sharpness': 3438.7113175056875, 'edge_count': 86363, 'edge_density': 0.6279551188151041, 'edge_orientation_std': 63.78207644537209}
# {'file_name': 'train_data/7d64aafcd2a3443a91629235cff9403c.jpg', 'label': 0, 'artifact_detection_lower_threshold': -8.517354962457546, 'artifact_detection_upper_threshold': 358.55971844715805, 'skewness': -0.4519519999376483, 'kurtosis': -1.6264078753586675, 'fourier_mean_magnitude': 6579.683890869412, 'fourier_max_magnitude': 68820529.0, 'texture_coherence_correlation': 0.9937083467364163, 'gray_level_non_uniformity': 0.13115682, 'fractal_dimension': 1.796491044522802, 'texture_entropy': 5.092979079131563, 'short_run_emphasis': 97.21403713738844, 'spatial_variance': 8537.341428323953, 'sharpness': 291.71634418268997, 'edge_count': 9318, 'edge_density': 0.11948903401692708, 'edge_orientation_std': 24.122304503632474}
# {'file_name': 'train_data/b57a2044c0294be78f28ea9eac43476e.jpg', 'label': 1, 'artifact_detection_lower_threshold': -28.21588132799448, 'artifact_detection_upper_threshold': 309.6476847134111, 'skewness': -0.15562405662635526, 'kurtosis': -1.2919938175497678, 'fourier_mean_magnitude': 10106.283260286667, 'fourier_max_magnitude': 55331037.0, 'texture_coherence_correlation': 0.9863620606273149, 'gray_level_non_uniformity': 0.023316499, 'fractal_dimension': 1.7915151477465472, 'texture_entropy': 7.285045475618176, 'short_run_emphasis': 13.393671425527382, 'spatial_variance': 7469.905504414132, 'sharpness': 858.3983758433154, 'edge_count': 32599, 'edge_density': 0.3477986653645833, 'edge_orientation_std': 43.85404354542779}
# {'file_name': 'train_data/8519672b13c547378081acea238f5f30.jpg', 'label': 0, 'artifact_detection_lower_threshold': -1.2777838098505754, 'artifact_detection_upper_threshold': 287.3309539627404, 'skewness': -0.6448913860513747, 'kurtosis': -1.2591156507385257, 'fourier_mean_magnitude': 7479.76839348414, 'fourier_max_magnitude': 54482604.0, 'texture_coherence_correlation': 0.9832983700810506, 'gray_level_non_uniformity': 0.02504288, 'fractal_dimension': 1.8211400991820295, 'texture_entropy': 6.588722557771236, 'short_run_emphasis': 19.53183403560412, 'spatial_variance': 5360.118480939398, 'sharpness': 827.9885145772921, 'edge_count': 35770, 'edge_density': 0.27980353242607525, 'edge_orientation_std': 42.442294425034426}
# {'file_name': 'train_data/11ee9a009cbd4b0cb6d47c7f3ae7cbe1.jpg', 'label': 0, 'artifact_detection_lower_threshold': -49.79044609096042, 'artifact_detection_upper_threshold': 78.18461113002292, 'skewness': 3.0711498182954378, 'kurtosis': 9.64450409287397, 'fourier_mean_magnitude': 3230.9776629959656, 'fourier_max_magnitude': 5582524.0, 'texture_coherence_correlation': 0.9868168403725934, 'gray_level_non_uniformity': 0.3528034, 'fractal_dimension': 1.2932961915043182, 'texture_entropy': 3.5238608802375966, 'short_run_emphasis': 926.2349535239701, 'spatial_variance': 1050.662916352248, 'sharpness': 118.85808308916683, 'edge_count': 6161, 'edge_density': 0.07582346598307292, 'edge_orientation_std': 19.263536326103505}
# {'file_name': 'train_data/3ec9ffb6b5294fa39410fbbb8ff41dce.jpg', 'label': 1, 'artifact_detection_lower_threshold': -93.8518341961989, 'artifact_detection_upper_threshold': 293.57978524600355, 'skewness': 0.3651882788285619, 'kurtosis': -1.5576494787391388, 'fourier_mean_magnitude': 8964.143952007968, 'fourier_max_magnitude': 39266890.0, 'texture_coherence_correlation': 0.9901354892897894, 'gray_level_non_uniformity': 0.029768478, 'fractal_dimension': 1.6649373206416198, 'texture_entropy': 6.584016606688818, 'short_run_emphasis': 24.145509077502542, 'spatial_variance': 9581.606841886389, 'sharpness': 561.624914633414, 'edge_count': 14595, 'edge_density': 0.1974207560221354, 'edge_orientation_std': 29.662026160322405}
# {'file_name': 'train_data/3c63852b27904cfb96092f2cbc548949.jpg', 'label': 0, 'artifact_detection_lower_threshold': 28.228661353175667, 'artifact_detection_upper_threshold': 248.9779426507306, 'skewness': -0.4050032812542691, 'kurtosis': -0.7827634483904338, 'fourier_mean_magnitude': 9154.61311733087, 'fourier_max_magnitude': 54499623.0, 'texture_coherence_correlation': 0.966537583500261, 'gray_level_non_uniformity': 0.00503909, 'fractal_dimension': 1.8500656268591051, 'texture_entropy': 7.758063691200016, 'short_run_emphasis': 1.330138442229686, 'spatial_variance': 3273.4276446701065, 'sharpness': 918.4297408821425, 'edge_count': 51716, 'edge_density': 0.5305735270182291, 'edge_orientation_std': 54.10288137017861}
# {'file_name': 'train_data/f00bce7fd91149cfb843ff6480c50e9c.jpg', 'label': 0, 'artifact_detection_lower_threshold': 78.83635547680714, 'artifact_detection_upper_threshold': 347.70442710486896, 'skewness': -1.602609533649655, 'kurtosis': 1.135729777789642, 'fourier_mean_magnitude': 15896.394317249958, 'fourier_max_magnitude': 115308029.0, 'texture_coherence_correlation': 0.9251763527779537, 'gray_level_non_uniformity': 0.32511365, 'fractal_dimension': 1.938259506054604, 'texture_entropy': 4.3102851890737295, 'short_run_emphasis': 611.7043586512314, 'spatial_variance': 5034.464173431646, 'sharpness': 4319.721206202652, 'edge_count': 47062, 'edge_density': 0.23157293146306818, 'edge_orientation_std': 42.37719740506291}
# {'file_name': 'train_data/763eb0f4e8644e2b8ff704a96bb27251.jpg', 'label': 1, 'artifact_detection_lower_threshold': 2.8365332575120874, 'artifact_detection_upper_threshold': 330.30742324476654, 'skewness': -0.5176670767336249, 'kurtosis': -1.2373613531872063, 'fourier_mean_magnitude': 7041.772027341448, 'fourier_max_magnitude': 65498474.0, 'texture_coherence_correlation': 0.9904778926051219, 'gray_level_non_uniformity': 0.013498474, 'fractal_dimension': 1.8047860915088212, 'texture_entropy': 7.214227635006434, 'short_run_emphasis': 30.475595605480805, 'spatial_variance': 6851.613176372498, 'sharpness': 275.32114107673345, 'edge_count': 13462, 'edge_density': 0.210296630859375, 'edge_orientation_std': 27.465677188811654}
# {'file_name': 'train_data/82c714ab73824c6990f78b6d4afe24af.jpg', 'label': 1, 'artifact_detection_lower_threshold': 39.31852149062897, 'artifact_detection_upper_threshold': 350.8521887551392, 'skewness': -1.3856458929997282, 'kurtosis': 0.5887926116055993, 'fourier_mean_magnitude': 7176.759794249835, 'fourier_max_magnitude': 76709737.0, 'texture_coherence_correlation': 0.9890556982037256, 'gray_level_non_uniformity': 0.074901626, 'fractal_dimension': 1.8886569132339464, 'texture_entropy': 6.217045091569343, 'short_run_emphasis': 185.6431467131934, 'spatial_variance': 6215.426476649001, 'sharpness': 467.5685278094218, 'edge_count': 15105, 'edge_density': 0.2023289998372396, 'edge_orientation_std': 28.73029674733655}
# {'file_name': 'train_data/f3fae548dea74d60940a60e7e44ac5b3.jpg', 'label': 1, 'artifact_detection_lower_threshold': 61.89918335829091, 'artifact_detection_upper_threshold': 342.0882230544695, 'skewness': -1.579065911406283, 'kurtosis': 1.3103728320994037, 'fourier_mean_magnitude': 11448.14932485242, 'fourier_max_magnitude': 79432755.0, 'texture_coherence_correlation': 0.9350304747773801, 'gray_level_non_uniformity': 0.068383165, 'fractal_dimension': 1.9173419471936286, 'texture_entropy': 6.106905580004447, 'short_run_emphasis': 27.488686282635722, 'spatial_variance': 5408.915593964921, 'sharpness': 1900.6449334075053, 'edge_count': 43005, 'edge_density': 0.36612701416015625, 'edge_orientation_std': 45.1560480792101}
# {'file_name': 'train_data/0df6f0d855144e68b0a6e016548d5469.jpg', 'label': 1, 'artifact_detection_lower_threshold': -15.46359546689493, 'artifact_detection_upper_threshold': 282.52019992291343, 'skewness': -0.3301274466015302, 'kurtosis': -1.2678059012664293, 'fourier_mean_magnitude': 10944.336694289386, 'fourier_max_magnitude': 44299819.0, 'texture_coherence_correlation': 0.9410300463523311, 'gray_level_non_uniformity': 0.0051769894, 'fractal_dimension': 1.8669775651256018, 'texture_entropy': 7.792196101848553, 'short_run_emphasis': 2.2089531710353913, 'spatial_variance': 6174.598374282373, 'sharpness': 2295.0550425255415, 'edge_count': 45810, 'edge_density': 0.42184485918209874, 'edge_orientation_std': 48.67023937905766}
# {'file_name': 'train_data/7782530473f84e8791b3ad2c1960a79e.jpg', 'label': 1, 'artifact_detection_lower_threshold': -46.232844294789075, 'artifact_detection_upper_threshold': 261.49493907747586, 'skewness': 0.3841999040558298, 'kurtosis': -1.3221151683129777, 'fourier_mean_magnitude': 11402.61286022196, 'fourier_max_magnitude': 38353539.0, 'texture_coherence_correlation': 0.967961928594361, 'gray_level_non_uniformity': 0.00482155, 'fractal_dimension': 1.7380428076626375, 'texture_entropy': 7.840967939677984, 'short_run_emphasis': 2.3811654041342587, 'spatial_variance': 6362.873679694348, 'sharpness': 1097.6818875698232, 'edge_count': 32294, 'edge_density': 0.3887532552083333, 'edge_orientation_std': 46.85791776074263}
# {'file_name': 'train_data/68a32f9ac33c4211957c661b7ffa0838.jpg', 'label': 0, 'artifact_detection_lower_threshold': 114.0434144471068, 'artifact_detection_upper_threshold': 318.3582116774197, 'skewness': -1.3845148113478358, 'kurtosis': 1.451767877247871, 'fourier_mean_magnitude': 4864.63827934099, 'fourier_max_magnitude': 116892026.0, 'texture_coherence_correlation': 0.9953338023257925, 'gray_level_non_uniformity': 0.20815398, 'fractal_dimension': 1.9277405095973132, 'texture_entropy': 5.026072118668546, 'short_run_emphasis': 329.5155338581955, 'spatial_variance': 2654.9895543726875, 'sharpness': 153.25669436676716, 'edge_count': 12584, 'edge_density': 0.10735714074337122, 'edge_orientation_std': 22.278057515106553}
# {'file_name': 'train_data/75260192ea2e4011ab45a68a89809417.jpg', 'label': 1, 'artifact_detection_lower_threshold': 22.487651482206132, 'artifact_detection_upper_threshold': 312.90498259168703, 'skewness': -0.3816318482644001, 'kurtosis': -0.823529709120308, 'fourier_mean_magnitude': 11570.694489414565, 'fourier_max_magnitude': 65941588.0, 'texture_coherence_correlation': 0.960937413998113, 'gray_level_non_uniformity': 0.066670686, 'fractal_dimension': 1.8778999533297847, 'texture_entropy': 6.3909986580142455, 'short_run_emphasis': 71.66098692001049, 'spatial_variance': 5734.516647505159, 'sharpness': 1858.2104832692937, 'edge_count': 46456, 'edge_density': 0.3599853515625, 'edge_orientation_std': 49.35482331657349}
# {'file_name': 'train_data/250cbcd1c1b04e1180a37c7e8ecb7cb7.jpg', 'label': 1, 'artifact_detection_lower_threshold': 16.56205141108987, 'artifact_detection_upper_threshold': 287.91036809648597, 'skewness': -0.14911486373550206, 'kurtosis': -1.4125922492725862, 'fourier_mean_magnitude': 6206.066415766905, 'fourier_max_magnitude': 61732071.0, 'texture_coherence_correlation': 0.988089995166752, 'gray_level_non_uniformity': 0.01032337, 'fractal_dimension': 1.8291968374251075, 'texture_entropy': 7.235711370754335, 'short_run_emphasis': 10.419943517651713, 'spatial_variance': 4712.048017473315, 'sharpness': 237.89605022111652, 'edge_count': 20868, 'edge_density': 0.2329718079229798, 'edge_orientation_std': 34.675196210009965}
# {'file_name': 'train_data/161eeb92726b43899f0ac0a3a5cad566.jpg', 'label': 1, 'artifact_detection_lower_threshold': -46.208843098049954, 'artifact_detection_upper_threshold': 231.92596549388327, 'skewness': 0.2428222357773383, 'kurtosis': -1.388666395563341, 'fourier_mean_magnitude': 16949.739730656962, 'fourier_max_magnitude': 36512342.0, 'texture_coherence_correlation': 0.9508393127878512, 'gray_level_non_uniformity': 0.009413587, 'fractal_dimension': 1.8152294481143685, 'texture_entropy': 7.50213013182996, 'short_run_emphasis': 1.5833349927035123, 'spatial_variance': 5731.425941061822, 'sharpness': 3289.757913323734, 'edge_count': 64284, 'edge_density': 0.528778076171875, 'edge_orientation_std': 64.42202918555112}
# {'file_name': 'train_data/f11bf4beb567418e8017638befbe9d98.jpg', 'label': 1, 'artifact_detection_lower_threshold': -18.812802804998512, 'artifact_detection_upper_threshold': 326.71099107811045, 'skewness': -0.3370991279170976, 'kurtosis': -1.4222937793256543, 'fourier_mean_magnitude': 12214.482944579106, 'fourier_max_magnitude': 60534745.0, 'texture_coherence_correlation': 0.9756019876726546, 'gray_level_non_uniformity': 0.015464984, 'fractal_dimension': 1.8185217061771832, 'texture_entropy': 7.4186307421647655, 'short_run_emphasis': 10.559970470132056, 'spatial_variance': 7875.30411851747, 'sharpness': 1288.502269897196, 'edge_count': 29817, 'edge_density': 0.3361867268880208, 'edge_orientation_std': 42.19483963414091}
# {'file_name': 'train_data/cfabb1ab11f24b07b7a4c878d806f862.jpg', 'label': 0, 'artifact_detection_lower_threshold': -5.482445951589824, 'artifact_detection_upper_threshold': 204.63263706382102, 'skewness': 0.3602027066197626, 'kurtosis': -1.0198570894035128, 'fourier_mean_magnitude': 5869.289846054831, 'fourier_max_magnitude': 37929781.0, 'texture_coherence_correlation': 0.9853338903966193, 'gray_level_non_uniformity': 0.0075535513, 'fractal_dimension': 1.7028023572335496, 'texture_entropy': 7.343534617609178, 'short_run_emphasis': 4.461001955631608, 'spatial_variance': 2856.6859528569285, 'sharpness': 292.8633442746999, 'edge_count': 17370, 'edge_density': 0.2232390372983871, 'edge_orientation_std': 33.14212501348375}
# {'file_name': 'train_data/45c5b57ac13541de85c29a39eec3ada2.jpg', 'label': 1, 'artifact_detection_lower_threshold': -10.618478248332622, 'artifact_detection_upper_threshold': 279.4765294636104, 'skewness': -0.009050801142662695, 'kurtosis': -1.1864074332771155, 'fourier_mean_magnitude': 5273.439727078245, 'fourier_max_magnitude': 49555112.0, 'texture_coherence_correlation': 0.9952685584099683, 'gray_level_non_uniformity': 0.0046444405, 'fractal_dimension': 1.6975374260603913, 'texture_entropy': 7.895437105783129, 'short_run_emphasis': 7.264000070066038, 'spatial_variance': 5331.04260293419, 'sharpness': 87.5943571169509, 'edge_count': 11434, 'edge_density': 0.19224175347222222, 'edge_orientation_std': 28.48781653878971}
# {'file_name': 'train_data/cbd4669cdd6e4393a90be6f0a45c41a8.jpg', 'label': 0, 'artifact_detection_lower_threshold': 28.924609878518595, 'artifact_detection_upper_threshold': 294.675125504546, 'skewness': -0.40075480160908505, 'kurtosis': -0.8208199760175523, 'fourier_mean_magnitude': 7595.198052509764, 'fourier_max_magnitude': 61631469.0, 'texture_coherence_correlation': 0.9857382486976508, 'gray_level_non_uniformity': 0.0062659937, 'fractal_dimension': 1.8764248797053036, 'texture_entropy': 7.644731261858055, 'short_run_emphasis': 5.2727904959514555, 'spatial_variance': 4663.465669221714, 'sharpness': 1187.7037442660233, 'edge_count': 37952, 'edge_density': 0.38671875, 'edge_orientation_std': 41.15589224570982}
# {'file_name': 'train_data/1a711a4c9eb3462faf4b844d3f5eaadb.jpg', 'label': 1, 'artifact_detection_lower_threshold': -21.06409083050275, 'artifact_detection_upper_threshold': 312.3999266052423, 'skewness': -0.27055385373335833, 'kurtosis': -1.3786423866449191, 'fourier_mean_magnitude': 8309.225888186314, 'fourier_max_magnitude': 57277748.0, 'texture_coherence_correlation': 0.9861427329333412, 'gray_level_non_uniformity': 0.0090691345, 'fractal_dimension': 1.7729959662774348, 'texture_entropy': 7.62137788860995, 'short_run_emphasis': 7.380474514136315, 'spatial_variance': 7126.87419305483, 'sharpness': 572.5048507504204, 'edge_count': 20095, 'edge_density': 0.23775227864583334, 'edge_orientation_std': 35.19609555996152}
# {'file_name': 'train_data/12450e5c5d3440628c96ccca8d7e5f2d.jpg', 'label': 0, 'artifact_detection_lower_threshold': -21.2849490166346, 'artifact_detection_upper_threshold': 139.1328036308924, 'skewness': 1.7209462976698746, 'kurtosis': 2.8093642217095276, 'fourier_mean_magnitude': 11852.301583348233, 'fourier_max_magnitude': 23169026.0, 'texture_coherence_correlation': 0.8691527507647756, 'gray_level_non_uniformity': 0.01055335, 'fractal_dimension': 1.5699067005935254, 'texture_entropy': 7.019923359117254, 'short_run_emphasis': 2.1988243010933193, 'spatial_variance': 2007.0966703096767, 'sharpness': 2752.355603421566, 'edge_count': 45856, 'edge_density': 0.33120473225911456, 'edge_orientation_std': 49.18447144453489}
# {'file_name': 'train_data/4463d542bf4349f7adc272a7e2cf62bb.jpg', 'label': 1, 'artifact_detection_lower_threshold': 31.963066945783027, 'artifact_detection_upper_threshold': 310.88310920167794, 'skewness': -0.6070031777909992, 'kurtosis': -0.4952630310178754, 'fourier_mean_magnitude': 7620.409095162864, 'fourier_max_magnitude': 67405913.0, 'texture_coherence_correlation': 0.9864164886426223, 'gray_level_non_uniformity': 0.022268413, 'fractal_dimension': 1.8558854236156808, 'texture_entropy': 7.031201985551967, 'short_run_emphasis': 28.530781180175772, 'spatial_variance': 5015.592539179753, 'sharpness': 451.70060434269385, 'edge_count': 15256, 'edge_density': 0.1530888875325521, 'edge_orientation_std': 30.57145141889518}
# {'file_name': 'train_data/dd2b2ad575f74f38ace2b44247bf8565.jpg', 'label': 1, 'artifact_detection_lower_threshold': 15.31788479329218, 'artifact_detection_upper_threshold': 226.19410861491093, 'skewness': 0.7771956318110491, 'kurtosis': 0.7924531937346551, 'fourier_mean_magnitude': 7000.474170166362, 'fourier_max_magnitude': 47482818.0, 'texture_coherence_correlation': 0.9735302706114235, 'gray_level_non_uniformity': 0.010102566, 'fractal_dimension': 1.6186767010664893, 'texture_entropy': 7.178026214691332, 'short_run_emphasis': 29.38288149549629, 'spatial_variance': 2956.1144688145723, 'sharpness': 642.5953669740248, 'edge_count': 24506, 'edge_density': 0.17279561360677084, 'edge_orientation_std': 38.73708786688173}
# {'file_name': 'train_data/263f2999ec184a68a132e3b959e2174a.jpg', 'label': 0, 'artifact_detection_lower_threshold': 1.4449016079152557, 'artifact_detection_upper_threshold': 263.5145873243764, 'skewness': -0.23609744211231956, 'kurtosis': -1.0997538330719332, 'fourier_mean_magnitude': 5485.5077832648185, 'fourier_max_magnitude': 48835975.0, 'texture_coherence_correlation': 0.9944798360591897, 'gray_level_non_uniformity': 0.0050870203, 'fractal_dimension': 1.8086394975797613, 'texture_entropy': 7.791295691330453, 'short_run_emphasis': 21.227812531361856, 'spatial_variance': 4382.11046206403, 'sharpness': 208.45036325984532, 'edge_count': 13222, 'edge_density': 0.20567762586805555, 'edge_orientation_std': 28.814114787057317}
# {'file_name': 'train_data/6830ed501cce48df8ec788249a6ba79f.jpg', 'label': 1, 'artifact_detection_lower_threshold': -17.23810199441951, 'artifact_detection_upper_threshold': 333.779229517206, 'skewness': -0.3557247476615351, 'kurtosis': -1.4386983586080522, 'fourier_mean_magnitude': 4741.554922178347, 'fourier_max_magnitude': 62233568.0, 'texture_coherence_correlation': 0.9973647693054083, 'gray_level_non_uniformity': 0.017157406, 'fractal_dimension': 1.7567071425712881, 'texture_entropy': 7.250768344812635, 'short_run_emphasis': 15.413624993618868, 'spatial_variance': 7755.465384158822, 'sharpness': 78.5809936206529, 'edge_count': 5525, 'edge_density': 0.13775126139322916, 'edge_orientation_std': 18.582444159020564}
# {'file_name': 'train_data/98e83203178c4a3f8b9d4ce24d0c8e3f.jpg', 'label': 1, 'artifact_detection_lower_threshold': -24.35676487508593, 'artifact_detection_upper_threshold': 334.99420078817184, 'skewness': -0.4974268264516928, 'kurtosis': -1.4530705248819078, 'fourier_mean_magnitude': 10672.258943521543, 'fourier_max_magnitude': 61075298.0, 'texture_coherence_correlation': 0.9800464806920419, 'gray_level_non_uniformity': 0.01539039, 'fractal_dimension': 1.8143748176952599, 'texture_entropy': 7.055642618318391, 'short_run_emphasis': 28.790014881151883, 'spatial_variance': 8477.10174894082, 'sharpness': 1505.7879451312474, 'edge_count': 32068, 'edge_density': 0.30269622802734375, 'edge_orientation_std': 38.92685510179463}
# {'file_name': 'train_data/a30bfcd09dbe46ed9122e10311aae856.jpg', 'label': 1, 'artifact_detection_lower_threshold': -45.724466922128585, 'artifact_detection_upper_threshold': 330.6449330272718, 'skewness': -0.21262018651419576, 'kurtosis': -1.5390595292994877, 'fourier_mean_magnitude': 7674.0445617646665, 'fourier_max_magnitude': 56017266.0, 'texture_coherence_correlation': 0.9945416921970972, 'gray_level_non_uniformity': 0.02193081, 'fractal_dimension': 1.773580792139005, 'texture_entropy': 7.123992707254626, 'short_run_emphasis': 27.907885158431128, 'spatial_variance': 9012.71719822823, 'sharpness': 272.81253452723223, 'edge_count': 18925, 'edge_density': 0.2735799153645833, 'edge_orientation_std': 33.96257317541116}
# {'file_name': 'train_data/0804ae3123614941b156638d37b5309b.jpg', 'label': 0, 'artifact_detection_lower_threshold': 26.68053374114173, 'artifact_detection_upper_threshold': 279.0907813630249, 'skewness': -0.17836900648097262, 'kurtosis': -1.243266019300984, 'fourier_mean_magnitude': 4585.920839879167, 'fourier_max_magnitude': 46966034.0, 'texture_coherence_correlation': 0.9950546542097511, 'gray_level_non_uniformity': 0.0052651204, 'fractal_dimension': 1.804627916980415, 'texture_entropy': 7.6952964108583535, 'short_run_emphasis': 5.4975247065803865, 'spatial_variance': 4052.7173644388404, 'sharpness': 99.47220400962829, 'edge_count': 10822, 'edge_density': 0.23986328125, 'edge_orientation_std': 31.197088017653986}
# {'file_name': 'train_data/c62cb86d069149a387d3eb02a2baa311.jpg', 'label': 1, 'artifact_detection_lower_threshold': 97.01079648208852, 'artifact_detection_upper_threshold': 330.84336001205213, 'skewness': -1.65143105932071, 'kurtosis': 1.903040196950383, 'fourier_mean_magnitude': 6689.009362814749, 'fourier_max_magnitude': 84119260.0, 'texture_coherence_correlation': 0.9868384301527348, 'gray_level_non_uniformity': 0.15354334, 'fractal_dimension': 1.9278554629982128, 'texture_entropy': 5.38587956639413, 'short_run_emphasis': 203.92001979540993, 'spatial_variance': 3536.945542737738, 'sharpness': 364.3005531901079, 'edge_count': 16993, 'edge_density': 0.17630513509114584, 'edge_orientation_std': 33.013533418102476}
# {'file_name': 'train_data/f3865d53608042179481728b37114da0.jpg', 'label': 0, 'artifact_detection_lower_threshold': -8.232169287836683, 'artifact_detection_upper_threshold': 277.7611152106882, 'skewness': -0.44139693116102513, 'kurtosis': -1.313034778313274, 'fourier_mean_magnitude': 6261.620582877117, 'fourier_max_magnitude': 52989929.0, 'texture_coherence_correlation': 0.9904150062957536, 'gray_level_non_uniformity': 0.005956623, 'fractal_dimension': 1.7657487683524598, 'texture_entropy': 7.656640213340396, 'short_run_emphasis': 4.157459624586733, 'spatial_variance': 5210.381061073697, 'sharpness': 329.7409073063689, 'edge_count': 9681, 'edge_density': 0.17308807373046875, 'edge_orientation_std': 23.86427691399489}
# {'file_name': 'train_data/18f2b28537d34e5ba5f7d425ed7ccae4.jpg', 'label': 1, 'artifact_detection_lower_threshold': -61.41971870697485, 'artifact_detection_upper_threshold': 247.40187502550555, 'skewness': 0.5561366732227153, 'kurtosis': -1.1572356616023662, 'fourier_mean_magnitude': 14044.128702725742, 'fourier_max_magnitude': 21711494.0, 'texture_coherence_correlation': 0.9222924281685555, 'gray_level_non_uniformity': 0.0070047304, 'fractal_dimension': 1.7385235650741677, 'texture_entropy': 7.626959345010192, 'short_run_emphasis': 1.9566611267910352, 'spatial_variance': 6883.859081949811, 'sharpness': 4459.479823643756, 'edge_count': 33071, 'edge_density': 0.48532158031798245, 'edge_orientation_std': 55.01518201775895}
# {'file_name': 'train_data/12bfa36cb3a54570a337cc98b2b6589c.jpg', 'label': 1, 'artifact_detection_lower_threshold': 45.99184169672495, 'artifact_detection_upper_threshold': 304.79078668055365, 'skewness': -0.5648212780021804, 'kurtosis': -0.6420510025487838, 'fourier_mean_magnitude': 10017.909484509482, 'fourier_max_magnitude': 68965195.0, 'texture_coherence_correlation': 0.9677634177505953, 'gray_level_non_uniformity': 0.01759888, 'fractal_dimension': 1.8754972709085564, 'texture_entropy': 7.195627350700333, 'short_run_emphasis': 67.47179860835922, 'spatial_variance': 4507.523647851459, 'sharpness': 1238.8729506852042, 'edge_count': 35680, 'edge_density': 0.2986297607421875, 'edge_orientation_std': 44.34528031799126}
# {'file_name': 'train_data/9de194a6d83544b2842905083e1d1fc9.jpg', 'label': 1, 'artifact_detection_lower_threshold': -9.756389892750263, 'artifact_detection_upper_threshold': 321.2041997478934, 'skewness': -0.4436484075022122, 'kurtosis': -1.2098490997935478, 'fourier_mean_magnitude': 9753.028079861238, 'fourier_max_magnitude': 61227712.0, 'texture_coherence_correlation': 0.9880397777128033, 'gray_level_non_uniformity': 0.00892827, 'fractal_dimension': 1.805119015286197, 'texture_entropy': 7.600087738858778, 'short_run_emphasis': 16.839493893851333, 'spatial_variance': 7119.144472095703, 'sharpness': 934.0812846753333, 'edge_count': 40798, 'edge_density': 0.3815867106119792, 'edge_orientation_std': 45.63330922648599}
# {'file_name': 'train_data/16bbb531aa1f494f847ed4664eba8289.jpg', 'label': 1, 'artifact_detection_lower_threshold': -52.99066673464449, 'artifact_detection_upper_threshold': 322.4125417346445, 'skewness': -0.022305203779633225, 'kurtosis': -1.5352939857431103, 'fourier_mean_magnitude': 8390.74821042374, 'fourier_max_magnitude': 52970034.0, 'texture_coherence_correlation': 0.9914657610244544, 'gray_level_non_uniformity': 0.042500332, 'fractal_dimension': 1.7104094257743534, 'texture_entropy': 6.844919864915903, 'short_run_emphasis': 57.71448719210207, 'spatial_variance': 8975.2633371059, 'sharpness': 444.1926446142542, 'edge_count': 18513, 'edge_density': 0.22420501708984375, 'edge_orientation_std': 33.50421753801337}
# {'file_name': 'train_data/e5523e760b22421d9b41000e0c195cb4.jpg', 'label': 1, 'artifact_detection_lower_threshold': 70.74946143255303, 'artifact_detection_upper_threshold': 338.351394076887, 'skewness': -1.7362913249534975, 'kurtosis': 1.7224296588898378, 'fourier_mean_magnitude': 8790.083432092428, 'fourier_max_magnitude': 80432586.0, 'texture_coherence_correlation': 0.9763145699486171, 'gray_level_non_uniformity': 0.1925902, 'fractal_dimension': 1.9029994457868582, 'texture_entropy': 5.088328211892607, 'short_run_emphasis': 239.60877298416224, 'spatial_variance': 4690.941410006101, 'sharpness': 722.5683505336186, 'edge_count': 13801, 'edge_density': 0.1445948282877604, 'edge_orientation_std': 28.91747171495846}
# {'file_name': 'train_data/b6676c471306470b9d1dab61e4517184.jpg', 'label': 0, 'artifact_detection_lower_threshold': 79.04176638351458, 'artifact_detection_upper_threshold': 231.64178667638123, 'skewness': -0.6133954824070669, 'kurtosis': 0.23703041591944318, 'fourier_mean_magnitude': 7583.061819090348, 'fourier_max_magnitude': 61082315.0, 'texture_coherence_correlation': 0.9489418336162456, 'gray_level_non_uniformity': 0.0071784365, 'fractal_dimension': 1.9231325836053093, 'texture_entropy': 7.340888738590358, 'short_run_emphasis': 1.200609728180807, 'spatial_variance': 1680.3806836920103, 'sharpness': 697.2057062784248, 'edge_count': 91592, 'edge_density': 0.6029790242513021, 'edge_orientation_std': 82.08096070251362}
# {'file_name': 'train_data/1996241bbfb14cb9b05229b21b86aff2.jpg', 'label': 1, 'artifact_detection_lower_threshold': -6.429907971592598, 'artifact_detection_upper_threshold': 217.6503466109155, 'skewness': 0.5006083522594584, 'kurtosis': -1.0085008039040837, 'fourier_mean_magnitude': 14225.475052207175, 'fourier_max_magnitude': 41530977.0, 'texture_coherence_correlation': 0.7660355423989319, 'gray_level_non_uniformity': 0.005178684, 'fractal_dimension': 1.7914487168029436, 'texture_entropy': 7.7770662909572685, 'short_run_emphasis': 1.2417962421106086, 'spatial_variance': 4273.443355108709, 'sharpness': 5758.8419048641035, 'edge_count': 81098, 'edge_density': 0.6344248453776041, 'edge_orientation_std': 55.78481662791907}
# {'file_name': 'train_data/3c999b7932e74f2ba00e6ba4577e90da.jpg', 'label': 0, 'artifact_detection_lower_threshold': 119.71303883519546, 'artifact_detection_upper_threshold': 302.9869055549955, 'skewness': -1.4581954038726133, 'kurtosis': 1.8998753999776863, 'fourier_mean_magnitude': 4799.657288972336, 'fourier_max_magnitude': 124657811.0, 'texture_coherence_correlation': 0.991531855294799, 'gray_level_non_uniformity': 0.07857005, 'fractal_dimension': 1.9203774759257182, 'texture_entropy': 5.97089561086084, 'short_run_emphasis': 74.66558873066911, 'spatial_variance': 2132.3338822579603, 'sharpness': 129.80877850597642, 'edge_count': 8302, 'edge_density': 0.0745578342013889, 'edge_orientation_std': 18.880947504280645}
# {'file_name': 'train_data/414b762e4e6c47f68653b953210cb543.jpg', 'label': 1, 'artifact_detection_lower_threshold': -66.79641491766651, 'artifact_detection_upper_threshold': 343.55387137925504, 'skewness': -0.1005894222047319, 'kurtosis': -1.7814111908011228, 'fourier_mean_magnitude': 15434.456581316337, 'fourier_max_magnitude': 54412764.0, 'texture_coherence_correlation': 0.9613284341454037, 'gray_level_non_uniformity': 0.044007834, 'fractal_dimension': 1.8069411260112391, 'texture_entropy': 6.492045066134621, 'short_run_emphasis': 118.10498288322556, 'spatial_variance': 11216.51966165658, 'sharpness': 3902.547441891957, 'edge_count': 51329, 'edge_density': 0.3883921305338542, 'edge_orientation_std': 49.977251576921844}
# {'file_name': 'train_data/557799041430450ab07139466b2d6bf6.jpg', 'label': 0, 'artifact_detection_lower_threshold': 76.27543438048433, 'artifact_detection_upper_threshold': 236.38338248692014, 'skewness': -0.7127590847212614, 'kurtosis': -0.035775248522194936, 'fourier_mean_magnitude': 13209.057768893595, 'fourier_max_magnitude': 92206349.0, 'texture_coherence_correlation': 0.9028895387663252, 'gray_level_non_uniformity': 0.0069882344, 'fractal_dimension': 1.8914753078517867, 'texture_entropy': 7.351335142559246, 'short_run_emphasis': 4.724566535587059, 'spatial_variance': 1914.5334071622513, 'sharpness': 3758.4941901489833, 'edge_count': 96862, 'edge_density': 0.4669918484157986, 'edge_orientation_std': 56.889550152676044}
# {'file_name': 'train_data/39ca16258666489fa954cd5f3e72b29c.jpg', 'label': 0, 'artifact_detection_lower_threshold': 135.065131198921, 'artifact_detection_upper_threshold': 300.2350468801231, 'skewness': -1.2133714016596897, 'kurtosis': 1.6693886630550647, 'fourier_mean_magnitude': 3208.418789884884, 'fourier_max_magnitude': 90931495.0, 'texture_coherence_correlation': 0.9955553041599674, 'gray_level_non_uniformity': 0.16880925, 'fractal_dimension': 1.9327747168684428, 'texture_entropy': 5.01973921647803, 'short_run_emphasis': 483.883655090782, 'spatial_variance': 1729.4929767273645, 'sharpness': 45.591576669730394, 'edge_count': 5724, 'edge_density': 0.06669826133578431, 'edge_orientation_std': 18.77976153627556}
# {'file_name': 'train_data/89208b2b93d64cffa7c2a6b0680d555b.jpg', 'label': 1, 'artifact_detection_lower_threshold': 1.9792280474754875, 'artifact_detection_upper_threshold': 345.5098110557146, 'skewness': -0.7507881145174895, 'kurtosis': -0.9776945105454775, 'fourier_mean_magnitude': 14405.856676527974, 'fourier_max_magnitude': 68319165.0, 'texture_coherence_correlation': 0.9591240670935481, 'gray_level_non_uniformity': 0.033748902, 'fractal_dimension': 1.8749167546122256, 'texture_entropy': 6.735242537473605, 'short_run_emphasis': 21.483852425673405, 'spatial_variance': 8008.627238271079, 'sharpness': 2490.134519928128, 'edge_count': 34762, 'edge_density': 0.301177978515625, 'edge_orientation_std': 42.21491728183373}
# {'file_name': 'train_data/3f1b934af1e24ae481d8f5d0f6438a17.jpg', 'label': 1, 'artifact_detection_lower_threshold': 40.53290696906484, 'artifact_detection_upper_threshold': 323.305690646495, 'skewness': -0.9662538821126581, 'kurtosis': -0.3500089669535713, 'fourier_mean_magnitude': 11674.530066418598, 'fourier_max_magnitude': 71531717.0, 'texture_coherence_correlation': 0.9502446432549246, 'gray_level_non_uniformity': 0.009418121, 'fractal_dimension': 1.8823434693919756, 'texture_entropy': 7.388583008009071, 'short_run_emphasis': 7.714820731933866, 'spatial_variance': 5421.497992860613, 'sharpness': 1894.3658744608983, 'edge_count': 25861, 'edge_density': 0.27915700276692706, 'edge_orientation_std': 37.558533591946215}
# {'file_name': 'train_data/4dc59b74fb7e4574a25489371ee2440a.jpg', 'label': 1, 'artifact_detection_lower_threshold': -18.30207574295771, 'artifact_detection_upper_threshold': 272.14105337502616, 'skewness': -0.13135569617647028, 'kurtosis': -1.323254534998569, 'fourier_mean_magnitude': 16683.718033612167, 'fourier_max_magnitude': 43665916.0, 'texture_coherence_correlation': 0.9390487655087921, 'gray_level_non_uniformity': 0.0044212304, 'fractal_dimension': 1.867588239022496, 'texture_entropy': 7.93233570984227, 'short_run_emphasis': 1.8119841155002492, 'spatial_variance': 6247.593724153346, 'sharpness': 4368.962165616596, 'edge_count': 76575, 'edge_density': 0.6635015578497023, 'edge_orientation_std': 70.0407468255151}
# {'file_name': 'train_data/95f7431ffb654f82b0ed8fda93263e28.jpg', 'label': 0, 'artifact_detection_lower_threshold': 33.82352111312372, 'artifact_detection_upper_threshold': 353.96532267756635, 'skewness': -1.0649505825428958, 'kurtosis': -0.2517639571606738, 'fourier_mean_magnitude': 6730.315355229315, 'fourier_max_magnitude': 76242179.0, 'texture_coherence_correlation': 0.9910698837704565, 'gray_level_non_uniformity': 0.26417366, 'fractal_dimension': 1.8664132837718508, 'texture_entropy': 4.663134642285783, 'short_run_emphasis': 422.066583739993, 'spatial_variance': 6500.99517687487, 'sharpness': 484.34691917583245, 'edge_count': 14521, 'edge_density': 0.1396052042643229, 'edge_orientation_std': 29.3826550021875}
# {'file_name': 'train_data/6efa1f712c6b4330a5a8d06a82312780.jpg', 'label': 1, 'artifact_detection_lower_threshold': 119.66017200157674, 'artifact_detection_upper_threshold': 297.1238241475811, 'skewness': -1.1916872119162145, 'kurtosis': 1.4185259416043339, 'fourier_mean_magnitude': 8862.304535121653, 'fourier_max_magnitude': 120352742.0, 'texture_coherence_correlation': 0.9751714127808075, 'gray_level_non_uniformity': 0.026253233, 'fractal_dimension': 1.9366175090005187, 'texture_entropy': 6.606155786244989, 'short_run_emphasis': 61.368778454386536, 'spatial_variance': 2125.9842003013014, 'sharpness': 632.7273270796106, 'edge_count': 24507, 'edge_density': 0.15525265957446807, 'edge_orientation_std': 29.97850074613107}
# {'file_name': 'train_data/adbbae4882ac46448f01889e43000d8f.jpg', 'label': 1, 'artifact_detection_lower_threshold': -79.56015016194712, 'artifact_detection_upper_threshold': 191.4469730786138, 'skewness': 1.0210798230949758, 'kurtosis': -0.50205797932299, 'fourier_mean_magnitude': 4019.4815288700115, 'fourier_max_magnitude': 17185156.0, 'texture_coherence_correlation': 0.99566031507106, 'gray_level_non_uniformity': 0.04634484, 'fractal_dimension': 1.6282683539050498, 'texture_entropy': 6.3462837561060255, 'short_run_emphasis': 6.576604452945892, 'spatial_variance': 4643.368874186028, 'sharpness': 117.05886673783195, 'edge_count': 10795, 'edge_density': 0.21633138020833334, 'edge_orientation_std': 29.815001178378605}
# {'file_name': 'train_data/7e0ce9365bf949d49e6baef5a847f314.jpg', 'label': 1, 'artifact_detection_lower_threshold': -87.76059000164791, 'artifact_detection_upper_threshold': 143.7239180452677, 'skewness': 2.609669530170598, 'kurtosis': 5.93215063438449, 'fourier_mean_magnitude': 6698.935475831228, 'fourier_max_magnitude': 11003505.0, 'texture_coherence_correlation': 0.9774559687252413, 'gray_level_non_uniformity': 0.31568864, 'fractal_dimension': 1.3821321884260858, 'texture_entropy': 3.5446919310203095, 'short_run_emphasis': 248.34748502380353, 'spatial_variance': 3491.7502902383953, 'sharpness': 439.90321941546995, 'edge_count': 14371, 'edge_density': 0.1404088338216146, 'edge_orientation_std': 27.605682848073783}
# {'file_name': 'train_data/59cf62d9841d42dbae8bc63283856731.jpg', 'label': 1, 'artifact_detection_lower_threshold': 26.532582941926478, 'artifact_detection_upper_threshold': 347.5932868090501, 'skewness': -1.1972896135763713, 'kurtosis': 0.01181081257683081, 'fourier_mean_magnitude': 9838.528479223058, 'fourier_max_magnitude': 73556102.0, 'texture_coherence_correlation': 0.9814748710363013, 'gray_level_non_uniformity': 0.033881225, 'fractal_dimension': 1.8941772940355033, 'texture_entropy': 6.695287243367931, 'short_run_emphasis': 28.09339327204768, 'spatial_variance': 6712.486977143188, 'sharpness': 859.4475175418515, 'edge_count': 23368, 'edge_density': 0.2243932088216146, 'edge_orientation_std': 38.61041188363628}
# {'file_name': 'train_data/199799e02e42476d9bbd48dad89c274c.jpg', 'label': 0, 'artifact_detection_lower_threshold': -27.220078373145952, 'artifact_detection_upper_threshold': 278.7345437051772, 'skewness': 0.10235088550425034, 'kurtosis': -1.170160189895125, 'fourier_mean_magnitude': 9181.358875465981, 'fourier_max_magnitude': 49448178.0, 'texture_coherence_correlation': 0.9859153894209541, 'gray_level_non_uniformity': 0.008915127, 'fractal_dimension': 1.7537492630346325, 'texture_entropy': 7.683334586548976, 'short_run_emphasis': 4.897029189749571, 'spatial_variance': 6068.5695264790365, 'sharpness': 497.7355073785616, 'edge_count': 25478, 'edge_density': 0.2971852620442708, 'edge_orientation_std': 40.13322531036982}
# {'file_name': 'train_data/0c8e3319c7e94669a9976490d4f35e16.jpg', 'label': 1, 'artifact_detection_lower_threshold': -48.6189032544397, 'artifact_detection_upper_threshold': 279.4380483693822, 'skewness': 0.20086803516725577, 'kurtosis': -1.4560965259604879, 'fourier_mean_magnitude': 13966.084423518938, 'fourier_max_magnitude': 41125722.0, 'texture_coherence_correlation': 0.9782739609355524, 'gray_level_non_uniformity': 0.006187711, 'fractal_dimension': 1.7545130746124757, 'texture_entropy': 7.72812875721953, 'short_run_emphasis': 4.573685189331977, 'spatial_variance': 7443.901289299658, 'sharpness': 2548.586382225201, 'edge_count': 49593, 'edge_density': 0.4453630118534483, 'edge_orientation_std': 54.45891829273509}
# {'file_name': 'train_data/ab64e1c21e444c7286de70f109b70fca.jpg', 'label': 1, 'artifact_detection_lower_threshold': -66.3585332515436, 'artifact_detection_upper_threshold': 155.04748234428556, 'skewness': 1.1308466500642098, 'kurtosis': 0.23711280507904053, 'fourier_mean_magnitude': 4302.781610667991, 'fourier_max_magnitude': 16892214.0, 'texture_coherence_correlation': 0.9941563783596038, 'gray_level_non_uniformity': 0.16589338, 'fractal_dimension': 1.4624057564634318, 'texture_entropy': 4.748847866681004, 'short_run_emphasis': 225.93715051948882, 'spatial_variance': 3119.473224261218, 'sharpness': 140.56045663813, 'edge_count': 8549, 'edge_density': 0.08441752772177419, 'edge_orientation_std': 22.745411017543315}
# {'file_name': 'train_data/8afc0598457a4f52afad7e4f15e3d874.jpg', 'label': 1, 'artifact_detection_lower_threshold': -40.86506681557759, 'artifact_detection_upper_threshold': 233.48101835366353, 'skewness': 0.2695740413671794, 'kurtosis': -1.134911336588422, 'fourier_mean_magnitude': 16009.138065783196, 'fourier_max_magnitude': 37871393.0, 'texture_coherence_correlation': 0.9149411572046319, 'gray_level_non_uniformity': 0.017866395, 'fractal_dimension': 1.7441751124008944, 'texture_entropy': 7.384166102458797, 'short_run_emphasis': 13.346114071567495, 'spatial_variance': 5435.534536357963, 'sharpness': 4697.048186241643, 'edge_count': 74776, 'edge_density': 0.5642445882161459, 'edge_orientation_std': 63.89720047617885}
# {'file_name': 'train_data/c72dcbfc176944abb754f140120079fe.jpg', 'label': 0, 'artifact_detection_lower_threshold': 79.10681817319839, 'artifact_detection_upper_threshold': 253.2303400299266, 'skewness': -0.6937298997594578, 'kurtosis': -0.050545114552313475, 'fourier_mean_magnitude': 11264.418527062056, 'fourier_max_magnitude': 65337873.0, 'texture_coherence_correlation': 0.9205667278032394, 'gray_level_non_uniformity': 0.006491218, 'fractal_dimension': 1.919554961240488, 'texture_entropy': 7.471425646735138, 'short_run_emphasis': 2.7302354497193253, 'spatial_variance': 2225.1570607471317, 'sharpness': 2974.4003052378735, 'edge_count': 78381, 'edge_density': 0.5751419067382812, 'edge_orientation_std': 63.37890750816943}
# {'file_name': 'train_data/4ede42d8b30d4021ab85fab24b392a65.jpg', 'label': 1, 'artifact_detection_lower_threshold': 36.38196375192754, 'artifact_detection_upper_threshold': 339.4219150322522, 'skewness': -0.7617596510176485, 'kurtosis': -0.9511198593016141, 'fourier_mean_magnitude': 8973.708343599974, 'fourier_max_magnitude': 73886367.0, 'texture_coherence_correlation': 0.9841960879017947, 'gray_level_non_uniformity': 0.13561705, 'fractal_dimension': 1.8800384350425468, 'texture_entropy': 5.843365914312904, 'short_run_emphasis': 184.98153925274, 'spatial_variance': 5967.59492490233, 'sharpness': 745.2109816390439, 'edge_count': 30482, 'edge_density': 0.2641805013020833, 'edge_orientation_std': 44.06143511844871}
# {'file_name': 'train_data/25c6b84aaa06412ab0069f6cce68ef3e.jpg', 'label': 1, 'artifact_detection_lower_threshold': 21.52479313505333, 'artifact_detection_upper_threshold': 308.4720432093477, 'skewness': -0.5123319564766535, 'kurtosis': -1.124227473134356, 'fourier_mean_magnitude': 12542.315065925819, 'fourier_max_magnitude': 64879739.0, 'texture_coherence_correlation': 0.9453696081329053, 'gray_level_non_uniformity': 0.0066470457, 'fractal_dimension': 1.8653676205931813, 'texture_entropy': 7.642404814117743, 'short_run_emphasis': 5.978769418943528, 'spatial_variance': 5742.857719257313, 'sharpness': 1677.2857982942369, 'edge_count': 48056, 'edge_density': 0.4044342041015625, 'edge_orientation_std': 51.132338343442015}
# {'file_name': 'train_data/cca3ebc47cac4e4691b87866762759b4.jpg', 'label': 0, 'artifact_detection_lower_threshold': 68.58902163026151, 'artifact_detection_upper_threshold': 306.1267118766829, 'skewness': -1.0981407421255902, 'kurtosis': 0.35623303996791256, 'fourier_mean_magnitude': 4588.393333750002, 'fourier_max_magnitude': 69066004.0, 'texture_coherence_correlation': 0.9938777463895015, 'gray_level_non_uniformity': 0.007976138, 'fractal_dimension': 1.9062051844101977, 'texture_entropy': 7.405188121048734, 'short_run_emphasis': 16.359257223138478, 'spatial_variance': 3585.700355402511, 'sharpness': 140.672159063014, 'edge_count': 6085, 'edge_density': 0.132275390625, 'edge_orientation_std': 18.443730727127537}
# {'file_name': 'train_data/7913ed391b7f4a96ac498ea0ea1b9fe6.jpg', 'label': 0, 'artifact_detection_lower_threshold': 102.34388946935107, 'artifact_detection_upper_threshold': 304.3323755407762, 'skewness': -2.844803057529621, 'kurtosis': 7.20733150994287, 'fourier_mean_magnitude': 3660.440549853612, 'fourier_max_magnitude': 89949438.0, 'texture_coherence_correlation': 0.9945128521618644, 'gray_level_non_uniformity': 0.032308396, 'fractal_dimension': 1.9264520527326636, 'texture_entropy': 5.837139081244332, 'short_run_emphasis': 115.02235547045585, 'spatial_variance': 2578.6268407928724, 'sharpness': 73.33140957404046, 'edge_count': 3336, 'edge_density': 0.03597231264467592, 'edge_orientation_std': 13.266023169203633}
# {'file_name': 'train_data/20b838e80c4247cf9c67b54345c38972.jpg', 'label': 1, 'artifact_detection_lower_threshold': -23.52660712946289, 'artifact_detection_upper_threshold': 329.8865467046582, 'skewness': -0.4552423237324556, 'kurtosis': -1.2539640063611606, 'fourier_mean_magnitude': 4439.950138746619, 'fourier_max_magnitude': 60232355.0, 'texture_coherence_correlation': 0.9976860907737388, 'gray_level_non_uniformity': 0.021551574, 'fractal_dimension': 1.7866834456726415, 'texture_entropy': 7.284864298369141, 'short_run_emphasis': 38.727995560035794, 'spatial_variance': 7868.247345255837, 'sharpness': 16.662965637838678, 'edge_count': 7861, 'edge_density': 0.23961893717447916, 'edge_orientation_std': 22.53627711510739}
# {'file_name': 'train_data/7cc2717e80364486b1d3f026f25436a7.jpg', 'label': 0, 'artifact_detection_lower_threshold': -5.272260884733839, 'artifact_detection_upper_threshold': 289.2084435426114, 'skewness': -0.12587431315260972, 'kurtosis': -1.137916743302545, 'fourier_mean_magnitude': 12141.131458509752, 'fourier_max_magnitude': 55823392.0, 'texture_coherence_correlation': 0.9717560904006541, 'gray_level_non_uniformity': 0.0046643848, 'fractal_dimension': 1.847522981324989, 'texture_entropy': 7.881304618826911, 'short_run_emphasis': 3.4431991259920953, 'spatial_variance': 5818.777403506968, 'sharpness': 2363.7242980131414, 'edge_count': 66117, 'edge_density': 0.5102996826171875, 'edge_orientation_std': 59.168378627560934}
# ...
# {'file_name': 'train_data/dd2cd1d246be4925bb3421aade9a9be5.jpg', 'label': 0, 'artifact_detection_lower_threshold': 95.04087650589584, 'artifact_detection_upper_threshold': 246.77095943160418, 'skewness': -1.064060373918745, 'kurtosis': 0.7573146601656955, 'fourier_mean_magnitude': 5508.766346333074, 'fourier_max_magnitude': 52500973.0, 'texture_coherence_correlation': 0.9761139617469913, 'gray_level_non_uniformity': 0.010085309, 'fractal_dimension': 1.9130598051524157, 'texture_entropy': 7.076447283359226, 'short_run_emphasis': 8.321990490913864, 'spatial_variance': 1567.9286224245602, 'sharpness': 377.4526948163245, 'edge_count': 20387, 'edge_density': 0.27895182291666665, 'edge_orientation_std': 38.777610988501145}
# {'file_name': 'train_data/fdfbc2edb00b488e9ef359ff0cbd9e98.jpg', 'label': 0, 'artifact_detection_lower_threshold': 76.26916700896344, 'artifact_detection_upper_threshold': 268.85933742625787, 'skewness': -0.7625096488872656, 'kurtosis': 0.2657807952395901, 'fourier_mean_magnitude': 9269.192918950974, 'fourier_max_magnitude': 67854346.0, 'texture_coherence_correlation': 0.936313078905628, 'gray_level_non_uniformity': 0.0063601076, 'fractal_dimension': 1.9121850361946366, 'texture_entropy': 7.517744925737658, 'short_run_emphasis': 3.851575769661878, 'spatial_variance': 2545.657055536259, 'sharpness': 1579.8220031790163, 'edge_count': 34972, 'edge_density': 0.30287933349609375, 'edge_orientation_std': 44.019424988248254}
# {'file_name': 'train_data/4f06ec9494634996b657550799a7255b.jpg', 'label': 1, 'artifact_detection_lower_threshold': 56.28336907563957, 'artifact_detection_upper_threshold': 355.96575100085784, 'skewness': -1.6134671418577553, 'kurtosis': 1.0166824232118152, 'fourier_mean_magnitude': 13292.994461931434, 'fourier_max_magnitude': 81049327.0, 'texture_coherence_correlation': 0.9631388230681227, 'gray_level_non_uniformity': 0.076750696, 'fractal_dimension': 1.9099352980699205, 'texture_entropy': 5.71886394044413, 'short_run_emphasis': 39.15290433357398, 'spatial_variance': 6143.83657722485, 'sharpness': 1999.7912733546302, 'edge_count': 26232, 'edge_density': 0.23889668782552084, 'edge_orientation_std': 37.05261609526146}
# {'file_name': 'train_data/739ffa95d2634b4cbdd3bedbf02044b9.jpg', 'label': 0, 'artifact_detection_lower_threshold': 50.173249323328776, 'artifact_detection_upper_threshold': 273.1146585949655, 'skewness': -1.4443337643301193, 'kurtosis': 1.3987870928557413, 'fourier_mean_magnitude': 4934.155290274567, 'fourier_max_magnitude': 63559459.0, 'texture_coherence_correlation': 0.991745434367656, 'gray_level_non_uniformity': 0.009741935, 'fractal_dimension': 1.8825744789016383, 'texture_entropy': 7.175488182949588, 'short_run_emphasis': 16.614450069028994, 'spatial_variance': 3162.9408722738667, 'sharpness': 158.36892475538966, 'edge_count': 9396, 'edge_density': 0.10640716552734375, 'edge_orientation_std': 23.13372737832975}
# {'file_name': 'train_data/1a06191e30db45d79537b44045878a19.jpg', 'label': 1, 'artifact_detection_lower_threshold': 83.23641377523289, 'artifact_detection_upper_threshold': 268.815800816501, 'skewness': -2.3573883343568944, 'kurtosis': 4.989884461025023, 'fourier_mean_magnitude': 9945.413553924307, 'fourier_max_magnitude': 67053877.0, 'texture_coherence_correlation': 0.9535341987300587, 'gray_level_non_uniformity': 0.37467995, 'fractal_dimension': 1.9328929303179847, 'texture_entropy': 3.5620590797991443, 'short_run_emphasis': 497.0053121104612, 'spatial_variance': 2500.06451315636, 'sharpness': 1321.23874848028, 'edge_count': 20444, 'edge_density': 0.16311743951612903, 'edge_orientation_std': 35.64870723202009}
# {'file_name': 'train_data/10d0a0cd0a3d4f398ba64d730e0800a9.jpg', 'label': 1, 'artifact_detection_lower_threshold': 139.30559712425486, 'artifact_detection_upper_threshold': 299.1905341858413, 'skewness': -3.1266695096016908, 'kurtosis': 9.603584069673326, 'fourier_mean_magnitude': 6626.177595037444, 'fourier_max_magnitude': 70044787.0, 'texture_coherence_correlation': 0.9739960175086978, 'gray_level_non_uniformity': 0.042302944, 'fractal_dimension': 1.936512445989604, 'texture_entropy': 5.545283833128616, 'short_run_emphasis': 124.29820577446161, 'spatial_variance': 1783.8265353680972, 'sharpness': 696.4083479428903, 'edge_count': 12776, 'edge_density': 0.16982171474358973, 'edge_orientation_std': 28.25043253822924}
# {'file_name': 'train_data/f1154c4dd9af4239bdbe1234c2fbf96e.jpg', 'label': 1, 'artifact_detection_lower_threshold': -12.247943002439598, 'artifact_detection_upper_threshold': 352.87846159781714, 'skewness': -0.775758461494195, 'kurtosis': -1.062503862854811, 'fourier_mean_magnitude': 13217.961590952264, 'fourier_max_magnitude': 66970137.0, 'texture_coherence_correlation': 0.9761190644189515, 'gray_level_non_uniformity': 0.022287704, 'fractal_dimension': 1.8414902554821244, 'texture_entropy': 6.861924161742213, 'short_run_emphasis': 20.523988927886812, 'spatial_variance': 8759.258973799742, 'sharpness': 1761.2217040422063, 'edge_count': 33642, 'edge_density': 0.30560302734375, 'edge_orientation_std': 46.239747565253765}
# {'file_name': 'train_data/393687d282204b29b36fa8c6dac654a3.jpg', 'label': 1, 'artifact_detection_lower_threshold': 42.63195561305949, 'artifact_detection_upper_threshold': 301.6511813905212, 'skewness': -0.9332175070142463, 'kurtosis': 0.6867171628987654, 'fourier_mean_magnitude': 6814.474282057864, 'fourier_max_magnitude': 67688041.0, 'texture_coherence_correlation': 0.9842379012127894, 'gray_level_non_uniformity': 0.10491286, 'fractal_dimension': 1.899193598966872, 'texture_entropy': 5.214152616096245, 'short_run_emphasis': 84.59412733071132, 'spatial_variance': 4323.65310935334, 'sharpness': 385.6925684359481, 'edge_count': 9866, 'edge_density': 0.12206268310546875, 'edge_orientation_std': 24.23430013997137}
# {'file_name': 'train_data/d1efa821806445d0b93acff5465c090f.jpg', 'label': 0, 'artifact_detection_lower_threshold': -53.05764675580268, 'artifact_detection_upper_threshold': 170.8596029325605, 'skewness': 2.027210408340791, 'kurtosis': 3.0074033437728636, 'fourier_mean_magnitude': 8792.06786478069, 'fourier_max_magnitude': 23160992.0, 'texture_coherence_correlation': 0.9565912371539306, 'gray_level_non_uniformity': 0.048005532, 'fractal_dimension': 1.4101072734740523, 'texture_entropy': 6.076005247114741, 'short_run_emphasis': 12.730606884495609, 'spatial_variance': 3413.650204810831, 'sharpness': 1383.4141898636333, 'edge_count': 19815, 'edge_density': 0.16322835286458334, 'edge_orientation_std': 32.04929381215183}
# {'file_name': 'train_data/e4fc72d255cb4a03b9e01a7e196c70d6.jpg', 'label': 1, 'artifact_detection_lower_threshold': 73.6852383645139, 'artifact_detection_upper_threshold': 349.75383837702253, 'skewness': -1.8360805938143698, 'kurtosis': 2.0925105077986323, 'fourier_mean_magnitude': 5505.911764747448, 'fourier_max_magnitude': 83251822.0, 'texture_coherence_correlation': 0.99098444059862, 'gray_level_non_uniformity': 0.093039356, 'fractal_dimension': 1.8904925524839373, 'texture_entropy': 5.60590846387108, 'short_run_emphasis': 48.376954717430536, 'spatial_variance': 4852.050010404214, 'sharpness': 183.8666978573634, 'edge_count': 19638, 'edge_density': 0.24782307942708334, 'edge_orientation_std': 34.48802295481849}
# {'file_name': 'train_data/7d59a4e0fc194a93b344026e3bef0668.jpg', 'label': 1, 'artifact_detection_lower_threshold': 69.74718124197462, 'artifact_detection_upper_threshold': 268.6230122394707, 'skewness': -1.469390504620285, 'kurtosis': 1.681487339271798, 'fourier_mean_magnitude': 15240.63065447263, 'fourier_max_magnitude': 66522976.0, 'texture_coherence_correlation': 0.8944617995598779, 'gray_level_non_uniformity': 0.009102971, 'fractal_dimension': 1.9379330867527453, 'texture_entropy': 7.262548653994864, 'short_run_emphasis': 11.541950468436024, 'spatial_variance': 3323.3802386853436, 'sharpness': 3653.136763060155, 'edge_count': 54803, 'edge_density': 0.44401804606119794, 'edge_orientation_std': 56.114486364502994}
# {'file_name': 'train_data/15ec92c60ed249fb89f288cf331f1fe4.jpg', 'label': 0, 'artifact_detection_lower_threshold': 119.38669885168254, 'artifact_detection_upper_threshold': 322.2349645597758, 'skewness': -1.5762739084438306, 'kurtosis': 2.0834204540275145, 'fourier_mean_magnitude': 4785.139330178768, 'fourier_max_magnitude': 86825445.0, 'texture_coherence_correlation': 0.9906096500252584, 'gray_level_non_uniformity': 0.294816, 'fractal_dimension': 1.9383328405096247, 'texture_entropy': 4.322155455634243, 'short_run_emphasis': 776.8516337967212, 'spatial_variance': 2629.2133755040704, 'sharpness': 222.34283955891928, 'edge_count': 13647, 'edge_density': 0.154998779296875, 'edge_orientation_std': 29.545417898995673}
# {'file_name': 'train_data/f4d72cde6fe247d69cd9927ff8b76bb6.jpg', 'label': 1, 'artifact_detection_lower_threshold': -16.545891381336133, 'artifact_detection_upper_threshold': 401.2917981300063, 'skewness': -1.1922351023719455, 'kurtosis': -0.5494446975809804, 'fourier_mean_magnitude': 9640.173828759815, 'fourier_max_magnitude': 111102796.0, 'texture_coherence_correlation': 0.9919602846805876, 'gray_level_non_uniformity': 0.45714962, 'fractal_dimension': 1.8293321128625546, 'texture_entropy': 2.417110354923699, 'short_run_emphasis': 985.9749542454662, 'spatial_variance': 11081.09647220407, 'sharpness': 405.8980009988858, 'edge_count': 8442, 'edge_density': 0.052668578235815604, 'edge_orientation_std': 18.854443691768093}
# {'file_name': 'train_data/a61481c842a44272ae7773381173e866.jpg', 'label': 0, 'artifact_detection_lower_threshold': 20.820500858168884, 'artifact_detection_upper_threshold': 241.4496566656083, 'skewness': 0.052906401724807664, 'kurtosis': -1.2405895357458276, 'fourier_mean_magnitude': 14643.114146120904, 'fourier_max_magnitude': 74123848.0, 'texture_coherence_correlation': 0.9387989000531901, 'gray_level_non_uniformity': 0.005874886, 'fractal_dimension': 1.770859603419015, 'texture_entropy': 7.623307788155321, 'short_run_emphasis': 5.932856334474761, 'spatial_variance': 3433.11249653268, 'sharpness': 2807.5734290591786, 'edge_count': 110286, 'edge_density': 0.5741656759510869, 'edge_orientation_std': 63.18025439907345}
# {'file_name': 'train_data/2115afd57426432da5f7e2220edb469f.jpg', 'label': 0, 'artifact_detection_lower_threshold': 17.405600824850268, 'artifact_detection_upper_threshold': 241.653308273457, 'skewness': -0.09626704096067895, 'kurtosis': -1.1803921541182856, 'fourier_mean_magnitude': 7796.213352166024, 'fourier_max_magnitude': 50932590.0, 'texture_coherence_correlation': 0.9794701989236995, 'gray_level_non_uniformity': 0.0053402786, 'fractal_dimension': 1.7856790781634293, 'texture_entropy': 7.677371751938544, 'short_run_emphasis': 1.855884674627413, 'spatial_variance': 3301.311792103341, 'sharpness': 611.7788517925203, 'edge_count': 38487, 'edge_density': 0.3958180745442708, 'edge_orientation_std': 49.23216551123796}
# {'file_name': 'train_data/c5cff63ca23a40d1b4dd2740c2e4043d.jpg', 'label': 0, 'artifact_detection_lower_threshold': 82.72427662703015, 'artifact_detection_upper_threshold': 282.4999105881391, 'skewness': -1.3758138803290298, 'kurtosis': 0.7821218475198184, 'fourier_mean_magnitude': 9016.46358265316, 'fourier_max_magnitude': 71804967.0, 'texture_coherence_correlation': 0.9569858196658309, 'gray_level_non_uniformity': 0.01092161, 'fractal_dimension': 1.9273449603076738, 'texture_entropy': 7.048300875606991, 'short_run_emphasis': 12.594803216095162, 'spatial_variance': 2706.7803381980434, 'sharpness': 1301.7692091595122, 'edge_count': 34756, 'edge_density': 0.266082763671875, 'edge_orientation_std': 43.49078596153261}
# Ensemble d'entraînement (train_data) après prétraitement :
#                                          file_name  label  \
# 0  train_data/a6dcb93f596a43249135678dfcfc17ea.jpg      1
# 1  train_data/041be3153810433ab146bc97d5af505c.jpg      0
#
#    artifact_detection_lower_threshold  artifact_detection_upper_threshold  \
# 0                           57.764822                          316.198262
# 1                            7.130812                          280.543739
#
#    skewness  kurtosis  fourier_mean_magnitude  fourier_max_magnitude  \
# 0 -1.047510 -0.024813              7990.23531             73523519.0
# 1  0.007268 -1.360943              6926.83575             56557173.0
#
#    texture_coherence_correlation  gray_level_non_uniformity  \
# 0                       0.978511                   0.012222
# 1                       0.988125                   0.005055
#
#    fractal_dimension  texture_entropy  short_run_emphasis  spatial_variance  \
# 0           1.894698         7.319673           10.367692       4347.185398
# 1           1.778167         7.771620            1.626137       4809.602728
#
#     sharpness  edge_count  edge_density  edge_orientation_std
# 0  531.542231       19418      0.264496             33.415875
# 1  303.605909       29195      0.399279             42.988589
# Ensemble d'évaluation (evaluation_data) après prétraitement :
#                                          file_name  label  \
# 0  train_data/19b29cb2dd6c45a69999e1e3608b0982.jpg      1
# 1  train_data/76d24375c7ce4aa19fa50092ce335afd.jpg      0
# 2  train_data/58f88e4050a845428bc891badc334265.jpg      0
# 3  train_data/1c1b16b50b7a4801a42346e3a90c6c4c.jpg      0
# 4  train_data/5a16c753699341598768065d9ea82e7a.jpg      1
#
#    artifact_detection_lower_threshold  artifact_detection_upper_threshold  \
# 0                           27.121674                          284.089004
# 1                          120.988385                          297.880206
# 2                           35.888023                          267.579524
# 3                           -6.906642                          204.200694
# 4                            2.796259                          216.328746
#
#    skewness  kurtosis  fourier_mean_magnitude  fourier_max_magnitude  \
# 0  0.345609 -1.614319             4157.427867             61186191.0
# 1 -2.642035  6.557785             5091.371418             82353079.0
# 2 -0.772369 -0.199721            13974.263159             89495310.0
# 3  0.609982 -0.326623             9856.058330             38788064.0
# 4  0.398602 -0.412931            13525.916513             43081709.0
#
#    texture_coherence_correlation  gray_level_non_uniformity  \
# 0                       0.997002                   0.017445
# 1                       0.983479                   0.027842
# 2                       0.946233                   0.005499
# 3                       0.958685                   0.005475
# 4                       0.879174                   0.005051
#
#    fractal_dimension  texture_entropy  short_run_emphasis  spatial_variance  \
# 0           1.805767         6.614374           50.175106       4161.592548
# 1           1.925840         5.993704           83.967224       2019.579498
# 2           1.899938         7.716340            1.378249       3668.724672
# 3           1.703078         7.681647            2.062597       3046.448060
# 4           1.830455         7.747028            1.250092       3499.064520
#
#      sharpness  edge_count  edge_density  edge_orientation_std
# 0    98.285614        4281      0.043470             16.813539
# 1   255.744473       14746      0.141741             29.477475
# 2  2211.803353       79193      0.552867             54.912268
# 3  1150.367856       56023      0.463041             57.203345
# 4  3438.711318       86363      0.627955             63.782076

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split


# Préparer les données
X_train = train_data_processed.drop(columns=['file_name', 'label'])  
y_train = train_data_processed['label']

X_eval = evaluation_data_processed.drop(columns=['file_name', 'label'])  
y_eval = evaluation_data_processed['label']

X_eval = X_eval.dropna()
y_eval = y_eval.loc[X_eval.index] 


from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=500,            
    max_depth=10,               
    min_samples_leaf=10,        
    max_features='sqrt',         
    max_samples=0.9,            
    n_jobs=-1,                  
    random_state=42,          
    verbose=1                   
)

rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_eval)

accuracy = accuracy_score(y_eval, y_pred)
report = classification_report(y_eval, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Classification Report:\n{report}")
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:    4.2s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done 500 out of 500 | elapsed:    0.2s finished
# Accuracy: 0.8145363408521303
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       186
#            1       0.83      0.82      0.82       213
#
#     accuracy                           0.81       399
#    macro avg       0.81      0.81      0.81       399
# weighted avg       0.81      0.81      0.81       399
